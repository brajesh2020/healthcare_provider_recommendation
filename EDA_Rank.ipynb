# %%
# import pandas lib as pd
import pandas as pd
import sklearn
# read by default 1st sheet of an excel file
# dataframe1 = pd.read_excel('E://REVA//Healthcare Providers Data For Anomaly Detection//Medicare1//2021_CA_Data.xlsx',sheet_name="Sheet1",header=0)
dataframe1 = pd.read_excel('E://GitHub//healthcare_provider_recommendation//2021_CA_Data.xlsx',sheet_name="data1",header=0)

# %%
dataframe1.head()
# Out:
#    Rndrng_NPI Rndrng_Prvdr_Last_Org_Name Rndrng_Prvdr_First_Name  \
# 0  1326080128                    Hekmati                   Arman
# 1  1316951171                     Kawana                    Alex
# 2  1396765996                   Qasabian                   Levon
# 3  1073542338                     Siegel                  Robert
# 4  1154418291                      Cheng                   Susan
#
#   Rndrng_Prvdr_MI Rndrng_Prvdr_Crdntls Rndrng_Prvdr_Gndr Rndrng_Prvdr_Ent_Cd  \
# 0             NaN                 M.D.                 M                   I
# 1               Y                  M.D                 M                   I
# 2             NaN                  M.D                 M                   I
# 3               J                 M.D.                 M                   I
# 4             NaN                 M.D.                 F                   I
#
#                    Rndrng_Prvdr_St1 Rndrng_Prvdr_St2 Rndrng_Prvdr_City  ...  \
# ...

# %%
dataframe1.columns
# Out:
# Index(['Rndrng_NPI', 'Rndrng_Prvdr_Last_Org_Name', 'Rndrng_Prvdr_First_Name',
#        'Rndrng_Prvdr_MI', 'Rndrng_Prvdr_Crdntls', 'Rndrng_Prvdr_Gndr',
#        'Rndrng_Prvdr_Ent_Cd', 'Rndrng_Prvdr_St1', 'Rndrng_Prvdr_St2',
#        'Rndrng_Prvdr_City', 'Rndrng_Prvdr_State_Abrvtn',
#        'Rndrng_Prvdr_State_FIPS', 'Rndrng_Prvdr_Zip5', 'Rndrng_Prvdr_RUCA',
#        'Rndrng_Prvdr_RUCA_Desc', 'Rndrng_Prvdr_Cntry', 'Rndrng_Prvdr_Type',
#        'Rndrng_Prvdr_Mdcr_Prtcptg_Ind', 'HCPCS_Cd', 'HCPCS_Desc',
#        'HCPCS_Drug_Ind', 'Place_Of_Srvc', 'Tot_Benes', 'Tot_Srvcs',
#        'Tot_Bene_Day_Srvcs', 'Avg_Sbmtd_Chrg', 'Avg_Mdcr_Alowd_Amt',
#        'Avg_Mdcr_Pymt_Amt', 'Avg_Mdcr_Stdzd_Amt', 'LAT', 'LNG',
#        'HCPCS_category', 'HCPCS_sub category', 'match'],
#       dtype='object')

# %%
# dataframe1.shape()

# %%
dataframe1['Rndrng_Prvdr_Zip5'].value_counts()
# Out:
# Rndrng_Prvdr_Zip5
# 92103    16207
# 90095    14172
# 94305    12771
# 90048    11945
# 93720    11248
# 95816    10787
# 94143     8472
# 92128     1978
# 95834      903
# 91304      720
# Name: count, dtype: int64

# %%
df1 = dataframe1[dataframe1['Rndrng_Prvdr_Zip5'] == 90095] #user input
#rslt_df = rslt_df[rslt_df['hp descr'] like  'patient'] #user input

print(df1[0:2])
# Out:
#        Rndrng_NPI Rndrng_Prvdr_Last_Org_Name Rndrng_Prvdr_First_Name  \
# 11945  1154453769                    Maddahi                 Jamshid
# 11946  1013193101                    Itagaki                 Brandon
#
#       Rndrng_Prvdr_MI Rndrng_Prvdr_Crdntls Rndrng_Prvdr_Gndr  \
# 11945             NaN                 M.D.                 M
# 11946               K                 M.D.                 M
#
#       Rndrng_Prvdr_Ent_Cd            Rndrng_Prvdr_St1 Rndrng_Prvdr_St2  \
# 11945                   I  100 Ucla Medical Plz # 410              NaN
# 11946                   I          10833 Le Conte Ave              NaN
#
#       Rndrng_Prvdr_City  ... Tot_Bene_Day_Srvcs  Avg_Sbmtd_Chrg  \
# 11945       Los Angeles  ...                126          100.00
# 11946       Los Angeles  ...                 17           25.35
#
#        Avg_Mdcr_Alowd_Amt  Avg_Mdcr_Pymt_Amt Avg_Mdcr_Stdzd_Amt      LAT  \
# 11945               51.31              51.31              50.28  34.0712
# ...

# %%
df1.describe()
# Out:
#          Rndrng_NPI  Rndrng_Prvdr_State_FIPS  Rndrng_Prvdr_Zip5  \
# count  1.417200e+04                  14172.0            14172.0
# mean   1.495331e+09                      6.0            90095.0
# std    2.865294e+08                      0.0                0.0
# min    1.003001e+09                      6.0            90095.0
# 25%    1.275567e+09                      6.0            90095.0
# 50%    1.497056e+09                      6.0            90095.0
# 75%    1.730546e+09                      6.0            90095.0
# max    1.992973e+09                      6.0            90095.0
#
#        Rndrng_Prvdr_RUCA     Tot_Benes     Tot_Srvcs  Tot_Bene_Day_Srvcs  \
# count            14172.0  14172.000000  14172.000000        14172.000000
# mean                 1.0     64.894157    207.793692           84.916384
# std                  0.0    299.228694   1418.361608          326.984140
# min                  1.0     11.000000     11.000000           11.000000
# ...

# %%
df1['Rndrng_Prvdr_Zip5'].value_counts()
# Out:
# Rndrng_Prvdr_Zip5
# 90095    14172
# Name: count, dtype: int64

# %%
df1['HCPCS_Desc'].value_counts()
# Out:
# HCPCS_Desc
# Established patient outpatient visit, total time 30-39 minutes                                                                       603
# Established patient outpatient visit, total time 20-29 minutes                                                                       492
# Established patient outpatient visit, total time 40-54 minutes                                                                       331
# New patient outpatient visit, total time 45-59 minutes                                                                               290
# Subsequent hospital inpatient care, typically 35 minutes per day                                                                     261
#                                                                                                                                     ...
# Radiological supervision and interpretation of mri guidance for insertion of needle                                                    1
# ...

# %%
df2=df1[df1["HCPCS_Desc"].str.contains("patient")]

# %%
df2.head()
# Out:
#        Rndrng_NPI Rndrng_Prvdr_Last_Org_Name Rndrng_Prvdr_First_Name  \
# 12608  1295154102                    Carroll                 William
# 12609  1295154102                    Carroll                 William
# 12671  1407879216                        Jen                  Joanna
# 12674  1528449709                  Escalante             Winnila May
# 12675  1528449709                  Escalante             Winnila May
#
#       Rndrng_Prvdr_MI Rndrng_Prvdr_Crdntls Rndrng_Prvdr_Gndr  \
# 12608             NaN                  NaN                 M
# 12609             NaN                  NaN                 M
# 12671               C                   MD                 F
# 12674               Q                 N.P.                 F
# 12675               Q                 N.P.                 F
#
#       Rndrng_Prvdr_Ent_Cd               Rndrng_Prvdr_St1 Rndrng_Prvdr_St2  \
# 12608                   I   200 Ucla Medical Plz Ste 420              NaN
# ...

# %%
df2.describe()
# Out:
#          Rndrng_NPI  Rndrng_Prvdr_State_FIPS  Rndrng_Prvdr_Zip5  \
# count  3.823000e+03                   3823.0             3823.0
# mean   1.505785e+09                      6.0            90095.0
# std    2.929540e+08                      0.0                0.0
# min    1.003001e+09                      6.0            90095.0
# 25%    1.235457e+09                      6.0            90095.0
# 50%    1.518260e+09                      6.0            90095.0
# 75%    1.765466e+09                      6.0            90095.0
# max    1.992973e+09                      6.0            90095.0
#
#        Rndrng_Prvdr_RUCA    Tot_Benes    Tot_Srvcs  Tot_Bene_Day_Srvcs  \
# count             3823.0  3823.000000  3823.000000         3823.000000
# mean                 1.0    58.209521   101.159037           99.025896
# std                  0.0    76.120246   203.852300          195.155317
# min                  1.0    11.000000    11.000000           11.000000
# ...

# %%
df2['HCPCS_Desc'].value_counts()
# Out:
# HCPCS_Desc
# Established patient outpatient visit, total time 30-39 minutes                                                                                                    603
# Established patient outpatient visit, total time 20-29 minutes                                                                                                    492
# Established patient outpatient visit, total time 40-54 minutes                                                                                                    331
# New patient outpatient visit, total time 45-59 minutes                                                                                                            290
# Subsequent hospital inpatient care, typically 35 minutes per day                                                                                                  261
# ...

# %%
df3=df2

# %%
df3.loc[:, 'Avg_Sbmtd_Chrg_rank_default'] = df3['Avg_Sbmtd_Chrg'].rank()
df3.loc[:, 'Tot_Bene_Day_Srvcs_rank_default'] = df3['Tot_Bene_Day_Srvcs'].rank()

# %%
df3.loc[:, 'Avg_Sbmtd_Chrg_rank_natop'] = df3['Avg_Sbmtd_Chrg'].rank(na_option='top')
df3.loc[:, 'Avg_Sbmtd_Chrg_rank_nabottom'] = df3['Avg_Sbmtd_Chrg'].rank(na_option='bottom')

# %%
df3.loc[:, 'Tot_Bene_Day_Srvcs_rank_natop'] = df3['Tot_Bene_Day_Srvcs'].rank(na_option='top')
df3.loc[:, 'Tot_Bene_Day_Srvcs_rank_nabottom'] = df3['Tot_Bene_Day_Srvcs'].rank(na_option='bottom')

# %%
df3.head()

# %%
# Import TfIdfVectorizer from scikit-learn

from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

#Replace NaN with an empty string
df3.loc[df3['HCPCS_Desc'].isnull(), 'HCPCS_Desc'] = ''

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(df3['HCPCS_Desc'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape

# %%
#Array mapping from feature integer indices to feature name.
tfidf_matrix_array = tfidf_matrix[1:50].toarray()
print(tfidf_matrix_array)

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim.shape

# %%
cosine_sim[1]

# %%
#Construct a reverse map of indices and movie titles
indices = pd.Series(df3.index, index=df3['HCPCS_Desc']).drop_duplicates()

# %%
indices[:10]

# %%
# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(HCPCS_Desc, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[HCPCS_Desc]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df3['HCPCS_Desc'].iloc[movie_indices]

# %%
get_recommendations('Anti-clotting management for patient taking warfarin')

# %%
# Filter the original dataframe based on conditions
filtered_df = df1[(df1['Rndrng_Prvdr_Zip5'] == 90095) & df1['HCPCS_Desc'].str.contains('patient', case=False, na=False)]

# Create a new dataframe using the filtered data
second_dataframe = pd.DataFrame(filtered_df)

# Reset the index of the new dataframe
second_dataframe.reset_index(drop=True, inplace=True)

# %%
second_dataframe.head()

# %%
second_dataframe['Avg_Sbmtd_Chrg_rank_default'] = second_dataframe['Avg_Sbmtd_Chrg'].rank()
second_dataframe['Avg_Sbmtd_Chrg_rank_natop'] = second_dataframe['Avg_Sbmtd_Chrg'].rank(na_option='top')
second_dataframe['Avg_Sbmtd_Chrg_rank_nabottom'] = second_dataframe['Avg_Sbmtd_Chrg'].rank(na_option='bottom')
second_dataframe.loc[:, 'Avg_Sbmtd_Chrg_rank_default'] = second_dataframe['Avg_Sbmtd_Chrg'].rank()
second_dataframe.loc[:, 'Avg_Sbmtd_Chrg_rank_natop'] = second_dataframe['Avg_Sbmtd_Chrg'].rank(na_option='top')
second_dataframe.loc[:, 'Avg_Sbmtd_Chrg_rank_nabottom'] = second_dataframe['Avg_Sbmtd_Chrg'].rank(na_option='bottom')

# %%
second_dataframe.head()

# %%
second_dataframe.describe()

# %%
# Assuming you have a DataFrame called df3
excel_filename = 'E://REVA//Healthcare Providers Data For Anomaly Detection//Medicare1//output1.xlsx'  # Specify the desired file name
second_dataframe.to_excel(excel_filename, index=False)
print(f"DataFrame exported to '{excel_filename}'")

# %%
# Find columns with the same values in all rows
columns_to_drop = second_dataframe.columns[second_dataframe.nunique() == 1]

# Drop the identified columns
second_dataframe.drop(columns=columns_to_drop, inplace=True)

# %%
second_dataframe.head()

# %%
second_dataframe.describe()

# %%
# bottom 5% of Avg_Sbmtd_Chrg
# and top 5% of Tot_Bene_Day_Srvcs
# to create a scorecard based on above logic

# second logic
# based on mode ( most occuring) of Avg_Sbmtd_Chrg
# 1400, 1400,1400,1400,1400,1400, 1390, 1450, 1490 - 
# anyone at mode is ok , then the second highest in the comparision is with highest number of Tot_Bene_Day_Srvcs
